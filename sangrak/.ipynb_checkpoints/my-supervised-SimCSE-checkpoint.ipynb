# %% [markdown]
# # SimCSE with SBERT

# %%
# !pip install sentence-transformers

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Dataset

# %%
from datasets import load_dataset
import torch
from torch.utils.data import Dataset, DataLoader

dataset = load_dataset("tweet_eval", "sentiment")
# Out:
# Reusing dataset tweet_eval (/home/rak/.cache/huggingface/datasets/tweet_eval/emoji/1.1.0/12aee5282b8784f3e95459466db4cdf45c6bf49719c25cdb0743d71ed0410343)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
import datasets
import random
import pandas as pd
from IPython.display import display, HTML

# show data
def show_random_elements(dataset, num_examples=20):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    for column, typ in dataset.features.items():
        if isinstance(typ, datasets.ClassLabel):
            df[column] = df[column].transform(lambda i: typ.names[i])
    display(HTML(df.to_html()))

# %%
show_random_elements(dataset['train'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Long lines mean good food. Tacos overload in Grand Central Market. #LA2016 #nomnom…</td>
#       <td>❤</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Aonair - hands down amazing wine, amazing vineyard and of course, the owner- Grant Long Jr. ️ him.…</td>
#       <td>❤</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>"Who Likes Peanuts" Good Morning Mi Gente Linda Y Fea, Today Is A Beautiful Morning Because…</td>
#       <td>😂</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Exploring the Hollywood sign and all around there today! More on my Insta story #TheOne…</td>
#       <td>😎</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Yahsha and his baby cousin Kaniyah meeting for the first time. They created a bond instantly @user</td>
#       <td>💕</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Found this picture of us. XOXO ️ #blackandmild #artists #friends #love @ Casa 0101 Theater</td>
#       <td>❤</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Cotton candy California sunset . #SUNSET #california #cottoncandyclouds #calilife…</td>
#       <td>😍</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>#tbt to the day I made it on TV doing what I love ️ #BeaverNation @ Oregon State University</td>
#       <td>❤</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>️Sun-Kissed #balayage for #irelandbaldwin using @user #bondultim8 and #lightmaster…</td>
#       <td>☀</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Such an amazing live performance! P A N I C A T T H E D I S C O ️ @ Mayan Nightclub</td>
#       <td>❤</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>'Bout a week ago under the electric sky #edc20 #edclv2016 #withdrawals @ Kinetic Field Vip Deck</td>
#       <td>✨</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Look who I ran into @ the beach love you, Vee @ La Jolla Beach San Diego CALIFORNIA</td>
#       <td>😍</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>CST fabricated lift spindles + spacers for 6.5 inches of lift. #SuperiorQuality #HandMade…</td>
#       <td>🇺🇸</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>.::ˢᴵᴳᴺᴬᵀᵁᴿᴱ ᶜᴸᴬˢˢᵞ ᴰᴿᴵᴺᴷ ᴵ ᴾᴵᶜᴷᴱᴰ ᵁᴾ ᶠᴿᴼᴹ ᴹᵞ ˢᴾᴱᶜᴵᴬᴸ ᴷ ::. @ Las…</td>
#       <td>💜</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Leaving beautiful Santa Barbara keeping this view in my heart and mind. @user</td>
#       <td>📷</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>#WWDC16 was an incredible conference put together by a team of thousands of people. My sincere thanks to everyone who helped make it. ️</td>
#       <td>❤</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>#TGIF Los Angeles...Have a Nice Day This can be you this Sunday....check us out @user</td>
#       <td>😉</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Christmas Eve with the Maleks. Happy heart. @ Palomino</td>
#       <td>💕</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>After volleyball pic with my princess @ Santa Monica Pier</td>
#       <td>😘</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Consistency is Key and live Free. @user #Cali#Kush @ ARIA Resort &amp;amp; Casino</td>
#       <td>📸</td>
#     </tr>
#   </tbody>
# </table>

# %%
from torch.utils.data import DataLoader
import math
from sentence_transformers import models, losses
from sentence_transformers import LoggingHandler, SentenceTransformer, util, InputExample
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator, TripletEvaluator
import logging
from datetime import datetime
import os
import gzip
import csv

#### Just some code to print debug information to stdout
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()])
#### /print debug information to stdout


#You can specify any huggingface/transformers pre-trained model here, for example, bert-base-uncased, roberta-base, xlm-roberta-base
model_name = 'bert-base-uncased'

model_save_path = 'output/training_simcse-'+datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Use Huggingface/transformers model (like BERT, RoBERTa, XLNet, XLM-R) for mapping tokens to embeddings
word_embedding_model = models.Transformer(model_name, max_seq_length=64)

# Apply mean pooling to get one fixed sized sentence vector
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# 2022-05-18 13:26:43 - Use pytorch device: cuda

# %% [markdown]
# For SimCSE, we create our train_samples with InputExamples that consists of two times the same sentences, i.e.
# ```
# train_samples = [InputExample(texts=["sent1", "sent1"]), InputExample(texts=["sent2", "sent2"]), ...]
# ````

# %%
import tqdm

def get_triplets_input_example(dataset): 
    triplets_input_examples = []
   
    dataset_list = pd.DataFrame(dataset).values.tolist()
    for index, anchor_data in enumerate(dataset):
        positive_dataset = dataset_list.copy()
        negative_dataset = dataset_list.copy()

        positive_dataset.pop(index)
        positive_list = [x[0] for x in positive_dataset if x[1] == anchor_data['label']]
        positive_item = random.choice(positive_list)

        negative_dataset.pop(index)
        negative_list = [x[0] for x in negative_dataset if x[1] != anchor_data['label']]
        negative_item = random.choice(negative_list)
        
        triplets_input_examples.append(InputExample(texts = [anchor_data['text'], positive_item, negative_item], label = anchor_data['label']))

    return triplets_input_examples

def get_input_example(dataset):
    input_examples = []
   
    for index, anchor_data in enumerate(dataset):
        input_examples.append(InputExample(texts = [anchor_data['text']], label = anchor_data['label']))

    return input_examples

# %%
# Read the AllNLI.tsv.gz file and create the training dataset
# We just pass sentence1 two times to InputExample and use MultipleNegativesRankingLoss
train_samples = []
dev_samples = []

print(type(dataset['train']))
logging.info("get train triplets input")
train_samples = get_input_example(dataset['train'])
logging.info("get validation triplets input")
eval_val_examples  = get_triplets_input_example(dataset['validation'])
logging.info("setting triplet evaluator")
dev_evaluator = TripletEvaluator.from_input_examples(eval_val_examples, batch_size=8, name='my_dev')
# dev_evaluator = EmbeddingSimilarityEvaluator.from_input_examples(eval_val_examples, batch_size=8, name='my_dev')
# Out:
# <class 'datasets.arrow_dataset.Dataset'>
# 2022-05-18 13:26:43 - get train triplets input
# 2022-05-18 13:26:45 - get validation triplets input
# 2022-05-18 13:26:49 - setting triplet evaluator

# %%
print(len(dataset['train']))
print(len(dataset['test']))
print(len(dataset['validation']))
print(dataset['validation'][0])
# Out:
# 45000
# 50000
# 5000
# {'text': 'A little throwback with my favourite person @ Water Wall', 'label': 0}

# %% [markdown]
# # Train

# %% [markdown]
# As loss, we use: MultipleNegativesRankingLoss
#
# Here, texts[0] and texts[1] are considered as positive pair, while all others are negatives in a batch

# %%
from transformers.optimization import AdamW

# Configure the training
train_batch_size = 32
num_epochs = 5

# Use MultipleNegativesRankingLoss for SimCSE
train_dataloader = DataLoader(train_samples, shuffle=True, batch_size=train_batch_size)
train_loss = losses.BatchAllTripletLoss(model)


warmup_steps = math.ceil(len(train_dataloader) * num_epochs * 0.1) #10% of train data for warm-up
logging.info("Warmup-steps: {}".format(warmup_steps))

logging.info("Performance before training")
dev_evaluator(model)

#optimizer
optimizer = AdamW(model.parameters(),
                    lr=5e-5,
                    eps=1e-8)

# Train the model
model.fit(train_objectives=[(train_dataloader, train_loss)],
          evaluator=dev_evaluator,
          epochs=num_epochs,
          evaluation_steps=100,
          warmup_steps=warmup_steps,
          output_path=model_save_path,
        #   optimizer_class=  ,
          )
# Out:
# 2022-05-18 13:26:49 - Warmup-steps: 704
# 2022-05-18 13:26:49 - Performance before training
# 2022-05-18 13:26:49 - TripletEvaluator: Evaluating the model on my_dev dataset:
# 2022-05-18 13:27:06 - Accuracy Cosine Distance:   	53.24
# 2022-05-18 13:27:06 - Accuracy Manhattan Distance:	52.84
# 2022-05-18 13:27:06 - Accuracy Euclidean Distance:	53.00
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1407 [00:00<?, ?it/s]
# 2022-05-18 13:27:12 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 100 steps:
# 2022-05-18 13:27:25 - Accuracy Cosine Distance:   	53.24
# 2022-05-18 13:27:25 - Accuracy Manhattan Distance:	52.80
# 2022-05-18 13:27:25 - Accuracy Euclidean Distance:	52.68
#
# 2022-05-18 13:27:25 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:27:32 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 200 steps:
# 2022-05-18 13:27:45 - Accuracy Cosine Distance:   	53.50
# 2022-05-18 13:27:45 - Accuracy Manhattan Distance:	54.26
# 2022-05-18 13:27:45 - Accuracy Euclidean Distance:	53.92
#
# 2022-05-18 13:27:46 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:27:52 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 300 steps:
# 2022-05-18 13:28:06 - Accuracy Cosine Distance:   	56.14
# 2022-05-18 13:28:06 - Accuracy Manhattan Distance:	55.92
# 2022-05-18 13:28:06 - Accuracy Euclidean Distance:	56.04
#
# 2022-05-18 13:28:06 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:28:12 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 400 steps:
# 2022-05-18 13:28:26 - Accuracy Cosine Distance:   	57.30
# 2022-05-18 13:28:26 - Accuracy Manhattan Distance:	56.96
# 2022-05-18 13:28:26 - Accuracy Euclidean Distance:	57.06
#
# 2022-05-18 13:28:26 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:28:32 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 500 steps:
# 2022-05-18 13:28:46 - Accuracy Cosine Distance:   	58.64
# 2022-05-18 13:28:46 - Accuracy Manhattan Distance:	58.02
# 2022-05-18 13:28:46 - Accuracy Euclidean Distance:	58.00
#
# 2022-05-18 13:28:46 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:28:53 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 600 steps:
# 2022-05-18 13:29:07 - Accuracy Cosine Distance:   	60.04
# 2022-05-18 13:29:07 - Accuracy Manhattan Distance:	60.04
# 2022-05-18 13:29:07 - Accuracy Euclidean Distance:	60.18
#
# 2022-05-18 13:29:07 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:29:14 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 700 steps:
# 2022-05-18 13:29:28 - Accuracy Cosine Distance:   	60.12
# 2022-05-18 13:29:28 - Accuracy Manhattan Distance:	59.62
# 2022-05-18 13:29:28 - Accuracy Euclidean Distance:	59.58
#
# 2022-05-18 13:29:34 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 800 steps:
# 2022-05-18 13:29:49 - Accuracy Cosine Distance:   	60.74
# 2022-05-18 13:29:49 - Accuracy Manhattan Distance:	59.64
# 2022-05-18 13:29:49 - Accuracy Euclidean Distance:	59.66
#
# 2022-05-18 13:29:49 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:29:55 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 900 steps:
# 2022-05-18 13:30:10 - Accuracy Cosine Distance:   	61.32
# 2022-05-18 13:30:10 - Accuracy Manhattan Distance:	60.50
# 2022-05-18 13:30:10 - Accuracy Euclidean Distance:	60.70
#
# 2022-05-18 13:30:10 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:30:16 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 1000 steps:
# 2022-05-18 13:30:30 - Accuracy Cosine Distance:   	60.38
# 2022-05-18 13:30:30 - Accuracy Manhattan Distance:	59.46
# 2022-05-18 13:30:30 - Accuracy Euclidean Distance:	59.56
#
# 2022-05-18 13:30:36 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 1100 steps:
# 2022-05-18 13:30:52 - Accuracy Cosine Distance:   	60.70
# 2022-05-18 13:30:52 - Accuracy Manhattan Distance:	60.40
# 2022-05-18 13:30:52 - Accuracy Euclidean Distance:	60.26
#
# 2022-05-18 13:30:57 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 1200 steps:
# 2022-05-18 13:31:12 - Accuracy Cosine Distance:   	61.24
# 2022-05-18 13:31:12 - Accuracy Manhattan Distance:	60.62
# 2022-05-18 13:31:12 - Accuracy Euclidean Distance:	60.80
#
# 2022-05-18 13:31:17 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 1300 steps:
# 2022-05-18 13:31:31 - Accuracy Cosine Distance:   	62.04
# 2022-05-18 13:31:31 - Accuracy Manhattan Distance:	60.86
# 2022-05-18 13:31:31 - Accuracy Euclidean Distance:	61.34
#
# 2022-05-18 13:31:31 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:31:38 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 0 after 1400 steps:
# 2022-05-18 13:31:53 - Accuracy Cosine Distance:   	61.58
# 2022-05-18 13:31:53 - Accuracy Manhattan Distance:	59.84
# 2022-05-18 13:31:53 - Accuracy Euclidean Distance:	60.00
#
# 2022-05-18 13:31:54 - TripletEvaluator: Evaluating the model on my_dev dataset after epoch 0:
# 2022-05-18 13:32:08 - Accuracy Cosine Distance:   	62.30
# 2022-05-18 13:32:08 - Accuracy Manhattan Distance:	61.00
# 2022-05-18 13:32:08 - Accuracy Euclidean Distance:	61.08
#
# 2022-05-18 13:32:08 - Save model to output/training_simcse-2022-05-18_13-26-37
# Iteration:   0%|          | 0/1407 [00:00<?, ?it/s]
# 2022-05-18 13:32:14 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 100 steps:
# 2022-05-18 13:32:28 - Accuracy Cosine Distance:   	63.14
# 2022-05-18 13:32:28 - Accuracy Manhattan Distance:	62.28
# 2022-05-18 13:32:28 - Accuracy Euclidean Distance:	62.46
#
# 2022-05-18 13:32:28 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:32:34 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 200 steps:
# 2022-05-18 13:32:49 - Accuracy Cosine Distance:   	63.52
# 2022-05-18 13:32:49 - Accuracy Manhattan Distance:	62.72
# 2022-05-18 13:32:49 - Accuracy Euclidean Distance:	62.76
#
# 2022-05-18 13:32:49 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:32:55 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 300 steps:
# 2022-05-18 13:33:09 - Accuracy Cosine Distance:   	63.26
# 2022-05-18 13:33:09 - Accuracy Manhattan Distance:	62.26
# 2022-05-18 13:33:09 - Accuracy Euclidean Distance:	62.62
#
# 2022-05-18 13:33:15 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 400 steps:
# 2022-05-18 13:33:29 - Accuracy Cosine Distance:   	64.06
# 2022-05-18 13:33:29 - Accuracy Manhattan Distance:	63.08
# 2022-05-18 13:33:29 - Accuracy Euclidean Distance:	63.20
#
# 2022-05-18 13:33:29 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:33:36 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 500 steps:
# 2022-05-18 13:33:50 - Accuracy Cosine Distance:   	63.08
# 2022-05-18 13:33:50 - Accuracy Manhattan Distance:	62.52
# 2022-05-18 13:33:50 - Accuracy Euclidean Distance:	62.74
#
# 2022-05-18 13:33:56 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 600 steps:
# 2022-05-18 13:34:10 - Accuracy Cosine Distance:   	63.32
# 2022-05-18 13:34:10 - Accuracy Manhattan Distance:	62.32
# 2022-05-18 13:34:10 - Accuracy Euclidean Distance:	62.60
#
# 2022-05-18 13:34:16 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 700 steps:
# 2022-05-18 13:34:31 - Accuracy Cosine Distance:   	63.76
# 2022-05-18 13:34:31 - Accuracy Manhattan Distance:	62.48
# 2022-05-18 13:34:31 - Accuracy Euclidean Distance:	62.68
#
# 2022-05-18 13:34:36 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 800 steps:
# 2022-05-18 13:34:51 - Accuracy Cosine Distance:   	63.46
# 2022-05-18 13:34:51 - Accuracy Manhattan Distance:	62.20
# 2022-05-18 13:34:51 - Accuracy Euclidean Distance:	62.16
#
# 2022-05-18 13:34:57 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 900 steps:
# 2022-05-18 13:35:12 - Accuracy Cosine Distance:   	62.70
# 2022-05-18 13:35:12 - Accuracy Manhattan Distance:	61.14
# 2022-05-18 13:35:12 - Accuracy Euclidean Distance:	61.50
#
# 2022-05-18 13:35:17 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 1000 steps:
# 2022-05-18 13:35:32 - Accuracy Cosine Distance:   	63.72
# 2022-05-18 13:35:32 - Accuracy Manhattan Distance:	62.96
# 2022-05-18 13:35:32 - Accuracy Euclidean Distance:	62.66
#
# 2022-05-18 13:35:38 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 1100 steps:
# 2022-05-18 13:35:52 - Accuracy Cosine Distance:   	63.46
# 2022-05-18 13:35:52 - Accuracy Manhattan Distance:	62.52
# 2022-05-18 13:35:52 - Accuracy Euclidean Distance:	62.56
#
# 2022-05-18 13:35:58 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 1200 steps:
# 2022-05-18 13:36:13 - Accuracy Cosine Distance:   	62.78
# 2022-05-18 13:36:13 - Accuracy Manhattan Distance:	62.02
# 2022-05-18 13:36:13 - Accuracy Euclidean Distance:	62.06
#
# 2022-05-18 13:36:19 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 1300 steps:
# 2022-05-18 13:36:33 - Accuracy Cosine Distance:   	64.04
# 2022-05-18 13:36:33 - Accuracy Manhattan Distance:	63.08
# 2022-05-18 13:36:33 - Accuracy Euclidean Distance:	63.22
#
# 2022-05-18 13:36:39 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 1 after 1400 steps:
# 2022-05-18 13:36:53 - Accuracy Cosine Distance:   	63.44
# 2022-05-18 13:36:53 - Accuracy Manhattan Distance:	62.56
# 2022-05-18 13:36:53 - Accuracy Euclidean Distance:	62.72
#
# 2022-05-18 13:36:54 - TripletEvaluator: Evaluating the model on my_dev dataset after epoch 1:
# 2022-05-18 13:37:09 - Accuracy Cosine Distance:   	63.40
# 2022-05-18 13:37:09 - Accuracy Manhattan Distance:	62.16
# 2022-05-18 13:37:09 - Accuracy Euclidean Distance:	62.28
# Iteration:   0%|          | 0/1407 [00:00<?, ?it/s]
# 2022-05-18 13:37:14 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 100 steps:
# 2022-05-18 13:37:29 - Accuracy Cosine Distance:   	63.92
# 2022-05-18 13:37:29 - Accuracy Manhattan Distance:	62.72
# 2022-05-18 13:37:29 - Accuracy Euclidean Distance:	62.72
#
# 2022-05-18 13:37:34 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 200 steps:
# 2022-05-18 13:37:49 - Accuracy Cosine Distance:   	64.64
# 2022-05-18 13:37:49 - Accuracy Manhattan Distance:	63.50
# 2022-05-18 13:37:49 - Accuracy Euclidean Distance:	63.68
#
# 2022-05-18 13:37:49 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:37:55 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 300 steps:
# 2022-05-18 13:38:09 - Accuracy Cosine Distance:   	64.02
# 2022-05-18 13:38:09 - Accuracy Manhattan Distance:	63.44
# 2022-05-18 13:38:09 - Accuracy Euclidean Distance:	63.24
#
# 2022-05-18 13:38:15 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 400 steps:
# 2022-05-18 13:38:29 - Accuracy Cosine Distance:   	63.76
# 2022-05-18 13:38:29 - Accuracy Manhattan Distance:	62.52
# 2022-05-18 13:38:29 - Accuracy Euclidean Distance:	62.82
#
# 2022-05-18 13:38:35 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 500 steps:
# 2022-05-18 13:38:49 - Accuracy Cosine Distance:   	64.10
# 2022-05-18 13:38:49 - Accuracy Manhattan Distance:	63.34
# 2022-05-18 13:38:49 - Accuracy Euclidean Distance:	63.42
#
# 2022-05-18 13:38:55 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 600 steps:
# 2022-05-18 13:39:08 - Accuracy Cosine Distance:   	64.16
# 2022-05-18 13:39:08 - Accuracy Manhattan Distance:	63.46
# 2022-05-18 13:39:08 - Accuracy Euclidean Distance:	63.90
#
# 2022-05-18 13:39:14 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 700 steps:
# 2022-05-18 13:39:28 - Accuracy Cosine Distance:   	64.26
# 2022-05-18 13:39:28 - Accuracy Manhattan Distance:	63.54
# 2022-05-18 13:39:28 - Accuracy Euclidean Distance:	63.66
#
# 2022-05-18 13:39:34 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 800 steps:
# 2022-05-18 13:39:49 - Accuracy Cosine Distance:   	63.76
# 2022-05-18 13:39:49 - Accuracy Manhattan Distance:	63.22
# 2022-05-18 13:39:49 - Accuracy Euclidean Distance:	63.56
#
# 2022-05-18 13:39:55 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 900 steps:
# 2022-05-18 13:40:10 - Accuracy Cosine Distance:   	63.50
# 2022-05-18 13:40:10 - Accuracy Manhattan Distance:	62.90
# 2022-05-18 13:40:10 - Accuracy Euclidean Distance:	63.44
#
# 2022-05-18 13:40:15 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 1000 steps:
# 2022-05-18 13:40:30 - Accuracy Cosine Distance:   	63.98
# 2022-05-18 13:40:30 - Accuracy Manhattan Distance:	63.46
# 2022-05-18 13:40:30 - Accuracy Euclidean Distance:	63.50
#
# 2022-05-18 13:40:36 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 1100 steps:
# 2022-05-18 13:40:51 - Accuracy Cosine Distance:   	63.80
# 2022-05-18 13:40:51 - Accuracy Manhattan Distance:	63.10
# 2022-05-18 13:40:51 - Accuracy Euclidean Distance:	62.90
#
# 2022-05-18 13:40:56 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 1200 steps:
# 2022-05-18 13:41:11 - Accuracy Cosine Distance:   	63.86
# 2022-05-18 13:41:11 - Accuracy Manhattan Distance:	63.68
# 2022-05-18 13:41:11 - Accuracy Euclidean Distance:	63.74
#
# 2022-05-18 13:41:17 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 1300 steps:
# 2022-05-18 13:41:32 - Accuracy Cosine Distance:   	64.28
# 2022-05-18 13:41:32 - Accuracy Manhattan Distance:	63.76
# 2022-05-18 13:41:32 - Accuracy Euclidean Distance:	64.00
#
# 2022-05-18 13:41:37 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 2 after 1400 steps:
# 2022-05-18 13:41:51 - Accuracy Cosine Distance:   	64.52
# 2022-05-18 13:41:51 - Accuracy Manhattan Distance:	64.08
# 2022-05-18 13:41:51 - Accuracy Euclidean Distance:	64.18
#
# 2022-05-18 13:41:52 - TripletEvaluator: Evaluating the model on my_dev dataset after epoch 2:
# 2022-05-18 13:42:05 - Accuracy Cosine Distance:   	64.28
# 2022-05-18 13:42:05 - Accuracy Manhattan Distance:	63.72
# 2022-05-18 13:42:05 - Accuracy Euclidean Distance:	63.90
# Iteration:   0%|          | 0/1407 [00:00<?, ?it/s]
# 2022-05-18 13:42:11 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 100 steps:
# 2022-05-18 13:42:26 - Accuracy Cosine Distance:   	64.00
# 2022-05-18 13:42:26 - Accuracy Manhattan Distance:	64.10
# 2022-05-18 13:42:26 - Accuracy Euclidean Distance:	64.04
#
# 2022-05-18 13:42:32 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 200 steps:
# 2022-05-18 13:42:46 - Accuracy Cosine Distance:   	64.02
# 2022-05-18 13:42:46 - Accuracy Manhattan Distance:	63.52
# 2022-05-18 13:42:46 - Accuracy Euclidean Distance:	63.72
#
# 2022-05-18 13:42:52 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 300 steps:
# 2022-05-18 13:43:06 - Accuracy Cosine Distance:   	64.02
# 2022-05-18 13:43:06 - Accuracy Manhattan Distance:	63.56
# 2022-05-18 13:43:06 - Accuracy Euclidean Distance:	63.68
#
# 2022-05-18 13:43:12 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 400 steps:
# 2022-05-18 13:43:26 - Accuracy Cosine Distance:   	64.08
# 2022-05-18 13:43:26 - Accuracy Manhattan Distance:	64.50
# 2022-05-18 13:43:26 - Accuracy Euclidean Distance:	64.48
#
# 2022-05-18 13:43:32 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 500 steps:
# 2022-05-18 13:43:47 - Accuracy Cosine Distance:   	64.82
# 2022-05-18 13:43:47 - Accuracy Manhattan Distance:	64.72
# 2022-05-18 13:43:47 - Accuracy Euclidean Distance:	64.54
#
# 2022-05-18 13:43:47 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:43:54 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 600 steps:
# 2022-05-18 13:44:08 - Accuracy Cosine Distance:   	64.54
# 2022-05-18 13:44:08 - Accuracy Manhattan Distance:	64.48
# 2022-05-18 13:44:08 - Accuracy Euclidean Distance:	64.38
#
# 2022-05-18 13:44:14 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 700 steps:
# 2022-05-18 13:44:28 - Accuracy Cosine Distance:   	64.38
# 2022-05-18 13:44:28 - Accuracy Manhattan Distance:	64.92
# 2022-05-18 13:44:28 - Accuracy Euclidean Distance:	64.64
#
# 2022-05-18 13:44:28 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:44:35 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 800 steps:
# 2022-05-18 13:44:49 - Accuracy Cosine Distance:   	64.70
# 2022-05-18 13:44:49 - Accuracy Manhattan Distance:	64.68
# 2022-05-18 13:44:49 - Accuracy Euclidean Distance:	64.56
#
# 2022-05-18 13:44:55 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 900 steps:
# 2022-05-18 13:45:09 - Accuracy Cosine Distance:   	64.28
# 2022-05-18 13:45:09 - Accuracy Manhattan Distance:	64.52
# 2022-05-18 13:45:09 - Accuracy Euclidean Distance:	64.14
#
# 2022-05-18 13:45:14 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 1000 steps:
# 2022-05-18 13:45:29 - Accuracy Cosine Distance:   	64.20
# 2022-05-18 13:45:29 - Accuracy Manhattan Distance:	63.88
# 2022-05-18 13:45:29 - Accuracy Euclidean Distance:	64.06
#
# 2022-05-18 13:45:35 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 1100 steps:
# 2022-05-18 13:45:49 - Accuracy Cosine Distance:   	64.12
# 2022-05-18 13:45:49 - Accuracy Manhattan Distance:	64.44
# 2022-05-18 13:45:49 - Accuracy Euclidean Distance:	64.18
#
# 2022-05-18 13:45:55 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 1200 steps:
# 2022-05-18 13:46:10 - Accuracy Cosine Distance:   	64.50
# 2022-05-18 13:46:10 - Accuracy Manhattan Distance:	64.70
# 2022-05-18 13:46:10 - Accuracy Euclidean Distance:	64.66
#
# 2022-05-18 13:46:16 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 1300 steps:
# 2022-05-18 13:46:30 - Accuracy Cosine Distance:   	64.44
# 2022-05-18 13:46:30 - Accuracy Manhattan Distance:	64.48
# 2022-05-18 13:46:30 - Accuracy Euclidean Distance:	64.58
#
# 2022-05-18 13:46:36 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 3 after 1400 steps:
# 2022-05-18 13:46:50 - Accuracy Cosine Distance:   	64.78
# 2022-05-18 13:46:50 - Accuracy Manhattan Distance:	64.50
# 2022-05-18 13:46:50 - Accuracy Euclidean Distance:	64.52
#
# 2022-05-18 13:46:51 - TripletEvaluator: Evaluating the model on my_dev dataset after epoch 3:
# 2022-05-18 13:47:05 - Accuracy Cosine Distance:   	64.74
# 2022-05-18 13:47:05 - Accuracy Manhattan Distance:	64.48
# 2022-05-18 13:47:05 - Accuracy Euclidean Distance:	64.52
# Iteration:   0%|          | 0/1407 [00:00<?, ?it/s]
# 2022-05-18 13:47:11 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 100 steps:
# 2022-05-18 13:47:25 - Accuracy Cosine Distance:   	65.02
# 2022-05-18 13:47:25 - Accuracy Manhattan Distance:	64.80
# 2022-05-18 13:47:25 - Accuracy Euclidean Distance:	64.96
#
# 2022-05-18 13:47:25 - Save model to output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:47:31 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 200 steps:
# 2022-05-18 13:47:45 - Accuracy Cosine Distance:   	64.80
# 2022-05-18 13:47:45 - Accuracy Manhattan Distance:	64.86
# 2022-05-18 13:47:45 - Accuracy Euclidean Distance:	64.78
#
# 2022-05-18 13:47:51 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 300 steps:
# 2022-05-18 13:48:05 - Accuracy Cosine Distance:   	64.30
# 2022-05-18 13:48:05 - Accuracy Manhattan Distance:	64.38
# 2022-05-18 13:48:05 - Accuracy Euclidean Distance:	64.22
#
# 2022-05-18 13:48:11 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 400 steps:
# 2022-05-18 13:48:26 - Accuracy Cosine Distance:   	64.50
# 2022-05-18 13:48:26 - Accuracy Manhattan Distance:	64.12
# 2022-05-18 13:48:26 - Accuracy Euclidean Distance:	64.38
#
# 2022-05-18 13:48:31 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 500 steps:
# 2022-05-18 13:48:45 - Accuracy Cosine Distance:   	64.20
# 2022-05-18 13:48:45 - Accuracy Manhattan Distance:	64.08
# 2022-05-18 13:48:45 - Accuracy Euclidean Distance:	64.26
#
# 2022-05-18 13:48:51 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 600 steps:
# 2022-05-18 13:49:06 - Accuracy Cosine Distance:   	64.06
# 2022-05-18 13:49:06 - Accuracy Manhattan Distance:	64.10
# 2022-05-18 13:49:06 - Accuracy Euclidean Distance:	63.84
#
# 2022-05-18 13:49:12 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 700 steps:
# 2022-05-18 13:49:27 - Accuracy Cosine Distance:   	64.34
# 2022-05-18 13:49:27 - Accuracy Manhattan Distance:	64.24
# 2022-05-18 13:49:27 - Accuracy Euclidean Distance:	64.18
#
# 2022-05-18 13:49:32 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 800 steps:
# 2022-05-18 13:49:48 - Accuracy Cosine Distance:   	64.52
# 2022-05-18 13:49:48 - Accuracy Manhattan Distance:	64.24
# 2022-05-18 13:49:48 - Accuracy Euclidean Distance:	64.46
#
# 2022-05-18 13:49:54 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 900 steps:
# 2022-05-18 13:50:09 - Accuracy Cosine Distance:   	64.30
# 2022-05-18 13:50:09 - Accuracy Manhattan Distance:	64.44
# 2022-05-18 13:50:09 - Accuracy Euclidean Distance:	64.48
#
# 2022-05-18 13:50:15 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 1000 steps:
# 2022-05-18 13:50:30 - Accuracy Cosine Distance:   	64.40
# 2022-05-18 13:50:30 - Accuracy Manhattan Distance:	64.26
# 2022-05-18 13:50:30 - Accuracy Euclidean Distance:	64.40
#
# 2022-05-18 13:50:36 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 1100 steps:
# 2022-05-18 13:50:50 - Accuracy Cosine Distance:   	64.44
# 2022-05-18 13:50:50 - Accuracy Manhattan Distance:	64.48
# 2022-05-18 13:50:50 - Accuracy Euclidean Distance:	64.34
#
# 2022-05-18 13:50:56 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 1200 steps:
# 2022-05-18 13:51:10 - Accuracy Cosine Distance:   	64.16
# 2022-05-18 13:51:10 - Accuracy Manhattan Distance:	64.54
# 2022-05-18 13:51:10 - Accuracy Euclidean Distance:	64.44
#
# 2022-05-18 13:51:16 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 1300 steps:
# 2022-05-18 13:51:30 - Accuracy Cosine Distance:   	64.30
# 2022-05-18 13:51:30 - Accuracy Manhattan Distance:	64.44
# 2022-05-18 13:51:30 - Accuracy Euclidean Distance:	64.40
#
# 2022-05-18 13:51:36 - TripletEvaluator: Evaluating the model on my_dev dataset in epoch 4 after 1400 steps:
# 2022-05-18 13:51:51 - Accuracy Cosine Distance:   	64.34
# 2022-05-18 13:51:51 - Accuracy Manhattan Distance:	64.44
# 2022-05-18 13:51:51 - Accuracy Euclidean Distance:	64.42
#
# 2022-05-18 13:51:51 - TripletEvaluator: Evaluating the model on my_dev dataset after epoch 4:
# 2022-05-18 13:52:06 - Accuracy Cosine Distance:   	64.34
# 2022-05-18 13:52:06 - Accuracy Manhattan Distance:	64.42
# 2022-05-18 13:52:06 - Accuracy Euclidean Distance:	64.44

# %%
##############################################################################
#
# Load the stored model and evaluate its performance on STS benchmark dataset
#
##############################################################################

model = SentenceTransformer(model_save_path)
logging.info("get test triplets input")
eval_test_examples  = get_triplets_input_example(dataset['test'])
# test_evaluator = TripletEvaluator.from_input_examples(test_samples, batch_size=train_batch_size, name='sts-test')
test_evaluator = TripletEvaluator.from_input_examples(eval_test_examples, batch_size=train_batch_size, name='my-test')
test_evaluator(model, output_path=model_save_path)
# Out:
# 2022-05-18 13:52:06 - Load pretrained SentenceTransformer: output/training_simcse-2022-05-18_13-26-37
# 2022-05-18 13:52:08 - Use pytorch device: cuda
# 2022-05-18 13:52:08 - get test triplets input
# 2022-05-18 14:02:07 - TripletEvaluator: Evaluating the model on my-test dataset:
# 2022-05-18 14:03:02 - Accuracy Cosine Distance:   	64.85
# 2022-05-18 14:03:02 - Accuracy Manhattan Distance:	64.74
# 2022-05-18 14:03:02 - Accuracy Euclidean Distance:	64.81
# 0.6485
